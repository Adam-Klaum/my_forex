# %%
import my_forex as myfx
from my_trader import Account, Strategy, add_sma, add_ema, add_atr, ma_55_20_cross, save_history_range
from datetime import date
from math import pi
import bokeh.plotting as bpl
import pandas as pd
import numpy as np;

bpl.reset_output()
bpl.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2faa7d5a-06c2-45fd-93f5-1ebb5c2a48a9">Loading BokehJS ...</span>
#     </div>

# %%
#df = myfx.fetch_candle('EUR_USD', granularity='M1', count=200)
#df.head()

# %%
save_history_range('EUR_USD',
                   'EUR_USD_2013_M5.csv',
                    date(2013, 1, 1),
                    date(2013, 12, 31),
                    granularity='M5',
                    price='BA')
# Out:
# 2013-01-01
# 2013-01-02
# 2013-01-03
# 2013-01-04
# 2013-01-05
# 2013-01-06
# 2013-01-07
# 2013-01-08
# 2013-01-09
# 2013-01-10
# 2013-01-11
# 2013-01-12
# 2013-01-13
# 2013-01-14
# 2013-01-15
# 2013-01-16
# 2013-01-17
# 2013-01-18
# 2013-01-19
# 2013-01-20
# 2013-01-21
# 2013-01-22
# 2013-01-23
# 2013-01-24
# 2013-01-25
# 2013-01-26
# 2013-01-27
# 2013-01-28
# 2013-01-29
# 2013-01-30
# 2013-01-31
# 2013-02-01
# 2013-02-02
# 2013-02-03
# 2013-02-04
# 2013-02-05
# 2013-02-06
# 2013-02-07
# 2013-02-08
# 2013-02-09
# 2013-02-10
# 2013-02-11
# 2013-02-12
# 2013-02-13
# 2013-02-14
# 2013-02-15
# 2013-02-16
# 2013-02-17
# 2013-02-18
# 2013-02-19
# 2013-02-20
# 2013-02-21
# 2013-02-22
# 2013-02-23
# 2013-02-24
# 2013-02-25
# 2013-02-26
# 2013-02-27
# 2013-02-28
# 2013-03-01
# 2013-03-02
# 2013-03-03
# 2013-03-04
# 2013-03-05
# 2013-03-06
# 2013-03-07
# 2013-03-08
# 2013-03-09
# 2013-03-10
# 2013-03-11
# 2013-03-12
# 2013-03-13
# 2013-03-14
# 2013-03-15
# 2013-03-16
# 2013-03-17
# ...

# %%
account = Account(2500)

strategy_001 = Strategy('1 min 55 SMA 20 EMA Cross',
                        'EUR_USD_2017.csv',
                        {add_sma: {'period': 55},
                         add_ema: {'period': 20},
                         add_atr: {'period': 14}},
                        .01,
                        account,
                        ma_55_20_cross,
                        '2017-01-01',
                        '2017-12-31',
                        '07:00',
                        '20:00',
                        1,
                        0,
                        10000,
                        20,
                        30)

strategy_001.load_history()
strategy_001.add_indicators()
#trade_df = strategy_001.run_strategy()

#df = strategy_001.df.copy()
# Out:
#                     instrument  bid_open  bid_high  bid_low  bid_close  \
# datetime
# 2017-12-21 15:55:00    EUR_USD   1.18547   1.18548  1.18539    1.18541
# 2017-12-21 15:56:00    EUR_USD   1.18546   1.18553  1.18538    1.18549
# 2017-12-21 15:57:00    EUR_USD   1.18546   1.18604  1.18546    1.18565
# 2017-12-21 15:58:00    EUR_USD   1.18560   1.18579  1.18550    1.18576
# 2017-12-21 15:59:00    EUR_USD   1.18574   1.18595  1.18564    1.18595
# 2017-12-21 16:00:00    EUR_USD   1.18598   1.18620  1.18595    1.18602
# 2017-12-21 16:01:00    EUR_USD   1.18602   1.18628  1.18602    1.18628
# 2017-12-21 16:02:00    EUR_USD   1.18628   1.18628  1.18588    1.18588
# 2017-12-21 16:03:00    EUR_USD   1.18584   1.18595  1.18579    1.18585
# 2017-12-21 16:04:00    EUR_USD   1.18583   1.18619  1.18583    1.18619
# 2017-12-21 16:05:00    EUR_USD   1.18622   1.18655  1.18620    1.18655
# 2017-12-21 16:06:00    EUR_USD   1.18655   1.18667  1.18654    1.18660
# ...

# %%
strategy_001.df.shape[0]
# Out:
# 4000

# %%
candle_df = df.iloc[-780:].copy()

p = myfx.plot_candle(candle_df, 'bid')
bpl.show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="35eec5f3-2a5e-45e5-addd-0af16ea15272"></div>
# </div>

# %%
trade_df.head(50)
# Out:
#             start_date            end_date trade_type lot_size  spread  \
# 0  2017-12-21 16:12:00 2017-12-21 19:59:00        BUY    10000     1.4
# 1  2017-12-21 17:29:00 2017-12-21 19:59:00        BUY    10000     1.4
# 2  2017-12-21 16:53:00 2017-12-21 19:59:00       SELL    10000     1.4
# 3  2017-12-21 17:46:00 2017-12-21 19:59:00       SELL    10000     1.2
# 4  2017-12-22 08:31:00 2017-12-22 15:13:00        BUY    10000     1.3
# 5  2017-12-22 09:23:00 2017-12-22 15:13:00        BUY    10000     1.4
# 6  2017-12-22 07:02:00 2017-12-22 15:57:00       SELL    10000     1.2
# 7  2017-12-22 09:15:00 2017-12-22 17:09:00       SELL    10000     1.2
# 8  2017-12-22 16:22:00 2017-12-22 17:12:00       SELL    10000     1.5
# 9  2017-12-22 16:07:00 2017-12-22 19:59:00        BUY    10000     1.5
# 10 2017-12-22 18:46:00 2017-12-22 19:59:00       SELL    10000     1.4
# 11 2017-12-22 16:31:00 2017-12-22 19:59:00        BUY    10000     1.4
# ...

# %%
trade_df['profit_loss'].sum()
# Out:
# -47.00000000000105
